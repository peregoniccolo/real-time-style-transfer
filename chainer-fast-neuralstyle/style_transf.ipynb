# %% [markdown]
# # Real-time-style-trainsfer model training

# %% [markdown]
# ## Repo connection
# You can obtain the repo cloning it with
#
#
# ```
# !git clone https://github.com/peregoniccolo/real-time-style-transfer
# ```

# %%
import os

working_path = os.getcwd()
print(working_path)

if working_path == '/content':
    from google.colab import drive
    drive.mount('/content/drive')
    # change this path
    # %cd /content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle
    # %pip install chainer
# Out:
# /content
# Mounted at /content/drive
# /content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle
# Collecting chainer
#   Downloading chainer-7.8.1.tar.gz (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from chainer) (67.7.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from chainer) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from chainer) (3.12.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.23.5)
# Requirement already satisfied: protobuf>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (3.20.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from chainer) (1.16.0)
# Building wheels for collected packages: chainer
#   Building wheel for chainer (setup.py) ... done
#   Created wheel for chainer: filename=chainer-7.8.1-py3-none-any.whl size=967716 sha256=d1e8caeaf4299413d9eeae419776bac014d265792b7b614890bd626855b6cdf0
#   Stored in directory: /root/.cache/pip/wheels/c4/95/6a/16014db6f761c4e742755b64aac60dbe142da1df6c5919f790
# Successfully built chainer
# Installing collected packages: chainer
# Successfully installed chainer-7.8.1

# %% [markdown]
# ## Setup model

# %%
# one off
# !sh setup_model.sh
# Out:
# load VGG16 caffemodel
# copy weights
# Copy conv1_1
# Copy conv1_2
# Copy conv2_1
# Copy conv2_2
# Copy conv3_1
# Copy conv3_2
# Copy conv3_3
# Copy conv4_1
# Copy conv4_2
# Copy conv4_3
# Copy conv5_1
# Copy conv5_2
# Copy conv5_3
# save "vgg16.model"
# done

# %% [markdown]
# ## Setup dataset
# Downloads the MSCOCO dataset (80k images) and extracts it.
#
# `--force_unzip` is needed for each time we re-start the training after colab stopped.

# %%
# !sh setup_dataset.sh --force_unzip
# Out:
# dataset folder exists
# unzipping remaining
# Archive:  train2014.zip
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4c7fff3a13a1> in <cell line: 1>()
# ----> 1 get_ipython().system('sh setup_dataset.sh --force_unzip')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     201       os.close(child_pty)
#     202
# --> 203       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     204   finally:
#     205     epoll.close()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     231   while True:
#     232     try:
# --> 233       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     234       if result is not None:
#     235         return result
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     279   output_available = False
#     280
# --> 281   events = epoll.poll()
#     282   input_events = []
#     283   for _, event in events:
#
# KeyboardInterrupt:

# %% [markdown]
# In case of:
# ```
# setup_dataset.sh: 17: Syntax error: end of file unexpected (expecting "then")
# ```
# (Or similar errors on setup_model.sh) run the following cell.
# Then re-run the sh file.

# %%
# !sudo apt-get install dos2unix
# !dos2unix *.sh

# %%
# %ls coco/train2014
# Out:
# images/

# %% [markdown]
# Create `fs.list` file. This contains the handles for all the images int eh dataset.
#
# The `-f` options let's you overwrite it if needed. You don'have to run this every time, but it helps checking you have all the images ready when re-starting.

# %%
# !python list_pop.py -f #82783
# Out:
# reading dataset directory
# Traceback (most recent call last):
#   File "/content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle/list_pop.py", line 28, in <module>
#     fs = os.listdir(f'{dataset}/images')
# OSError: [Errno 5] Input/output error: './coco/train2014/images'

# %% [markdown]
# If the cell above gives:
#
# ```
# OSError: [Errno 5] Input/output error: './coco/train2014/images'
# ```
# don't worry. Just re-run it until it finishes (3-4 times).
#
# The goal is to have 82783 images in the dataset. If you don't something went wrong extracting (or if you reconnected, the runtime might not have been saved last time).
#
# Add the -f option to the previous command if you already created fs.list file for a dataset (can be specified with -d followed by the location, default: codo/train2014/)

# %% [markdown]
# # Training

# %%
# TEST
#!python ./train.py -s ./sample_images/altocumulus.jpg -o altocumulus_test -d coco/test100 -e 2 -c 2 -b 10 -g 0 -i models/altocumulus-test/final_altocumulus-test.model -r models/altocumulus-test/final_altocumulus-test.state

# !python ./train.py -s sample_images/onde-overlay_75_25.png -e 2 -g 0 -c 25 -b 10 --lambda_style 4 --lambda_feat 2 #-a #-i models/altocumulus/altocumulus.model -r models/altocumulus/altocumulus.state

# TODO bug seconda epoca bug non cancella
# TODO best
# TODO bug cambio numero checkpoint
# Out:
# found character "_" in the output name, replaced with "-" to avoid problems
# reading fs.list
# num traning images: 82783
# 8278 iterations, 2 epochs
# /usr/local/lib/python3.10/dist-packages/chainer/functions/connection/convolution_2d.py:295: PerformanceWarning: The best algo of conv fwd might not be selected due to lack of workspace size (8388608)
#   cuda.cudnn.convolution_forward(
# epoch 0
# Not enough models, not deleting anything
# Epoch 0,0/8278. Total loss: 75712928.0. Loss distribution: feat 0.019801920279860497, style 0.9721721410751343, tv 0.00125124619808048, pop 0.00677459267899394
# Epoch 0,1/8278. Total loss: 45643152.0. Loss distribution: feat 0.036620285362005234, style 0.9593595266342163, tv 0.002282102359458804, pop 0.0017381010111421347
# Epoch 0,2/8278. Total loss: 18433544.0. Loss distribution: feat 0.07016853243112564, style 0.9224221706390381, tv 0.006289915647357702, pop 0.0011193379759788513
# Epoch 0,3/8278. Total loss: 9409624.0. Loss distribution: feat 0.10636457055807114, style 0.8788873553276062, tv 0.013508109375834465, pop 0.001239954144693911
# Epoch 0,4/8278. Total loss: 7817620.5. Loss distribution: feat 0.11682120710611343, style 0.8652315735816956, tv 0.01715223677456379, pop 0.000794969208072871
# Epoch 0,5/8278. Total loss: 7083782.5. Loss distribution: feat 0.12459777295589447, style 0.855604887008667, tv 0.01931861974298954, pop 0.0004786958743352443
# Epoch 0,6/8278. Total loss: 6437526.0. Loss distribution: feat 0.11693578958511353, style 0.8612048029899597, tv 0.021575141698122025, pop 0.0002842675312422216
# Epoch 0,7/8278. Total loss: 6088021.5. Loss distribution: feat 0.14146670699119568, style 0.8348777294158936, tv 0.0233027171343565, pop 0.0003527858352754265
# Epoch 0,8/8278. Total loss: 5916535.0. Loss distribution: feat 0.14184869825839996, style 0.8336792588233948, tv 0.02419699914753437, pop 0.000275017082458362
# Epoch 0,9/8278. Total loss: 5626071.5. Loss distribution: feat 0.14929623901844025, style 0.8249523639678955, tv 0.02548406459391117, pop 0.00026728984084911644
# Epoch 0,10/8278. Total loss: 5559719.5. Loss distribution: feat 0.14652208983898163, style 0.8273428082466125, tv 0.025891875848174095, pop 0.00024323392426595092
# Epoch 0,11/8278. Total loss: 5323938.0. Loss distribution: feat 0.14487001299858093, style 0.8277626633644104, tv 0.027140971273183823, pop 0.00022631784668192267
# Epoch 0,12/8278. Total loss: 5321336.5. Loss distribution: feat 0.15389862656593323, style 0.8188570737838745, tv 0.027020318433642387, pop 0.00022397008433472365
# Epoch 0,13/8278. Total loss: 5227622.5. Loss distribution: feat 0.1611713021993637, style 0.8109359741210938, tv 0.027742896229028702, pop 0.0001498763303970918
# Epoch 0,14/8278. Total loss: 4989601.5. Loss distribution: feat 0.14842285215854645, style 0.8221699595451355, tv 0.029190942645072937, pop 0.00021628645481541753
# Epoch 0,15/8278. Total loss: 4913840.0. Loss distribution: feat 0.17100577056407928, style 0.7994612455368042, tv 0.029275061562657356, pop 0.0002578345884103328
# Epoch 0,16/8278. Total loss: 4939473.5. Loss distribution: feat 0.20547226071357727, style 0.7650526165962219, tv 0.029125504195690155, pop 0.0003496726858429611
# Epoch 0,17/8278. Total loss: 4735543.5. Loss distribution: feat 0.16776715219020844, style 0.8013031482696533, tv 0.03066425770521164, pop 0.0002654516138136387
# Epoch 0,18/8278. Total loss: 4707026.0. Loss distribution: feat 0.17221999168395996, style 0.7963768839836121, tv 0.03111482597887516, pop 0.0002881500404328108
# Epoch 0,19/8278. Total loss: 4610625.0. Loss distribution: feat 0.16008542478084564, style 0.8074691891670227, tv 0.03220366686582565, pop 0.00024177694285754114
# Epoch 0,20/8278. Total loss: 4528680.0. Loss distribution: feat 0.154313325881958, style 0.8126512765884399, tv 0.032712407410144806, pop 0.00032301063765771687
# Epoch 0,21/8278. Total loss: 4603602.0. Loss distribution: feat 0.1754736453294754, style 0.7920475602149963, tv 0.03224840387701988, pop 0.00023040191445033997
# Epoch 0,22/8278. Total loss: 4510341.5. Loss distribution: feat 0.17569731175899506, style 0.7909830808639526, tv 0.0330745093524456, pop 0.0002451276814099401
# Epoch 0,23/8278. Total loss: 4371378.5. Loss distribution: feat 0.1719360053539276, style 0.7938755750656128, tv 0.033864110708236694, pop 0.0003243168175686151
# Epoch 0,24/8278. Total loss: 4298176.5. Loss distribution: feat 0.18280479311943054, style 0.7827847599983215, tv 0.03412662446498871, pop 0.0002838983491528779
# Not enough models, not deleting anything
# Epoch 0,25/8278. Total loss: 4431096.0. Loss distribution: feat 0.17866915464401245, style 0.7873390316963196, tv 0.033839475363492966, pop 0.00015237813931889832
# Epoch 0,26/8278. Total loss: 4251226.5. Loss distribution: feat 0.1810755431652069, style 0.7838347554206848, tv 0.03484869375824928, pop 0.00024109661171678454
# Epoch 0,27/8278. Total loss: 4181828.0. Loss distribution: feat 0.159567728638649, style 0.8047844171524048, tv 0.035392019897699356, pop 0.00025585066759958863
# Epoch 0,28/8278. Total loss: 4154105.75. Loss distribution: feat 0.1747208535671234, style 0.7897499203681946, tv 0.035352155566215515, pop 0.00017712109547574073
# Epoch 0,29/8278. Total loss: 4162543.5. Loss distribution: feat 0.19371706247329712, style 0.7713140845298767, tv 0.03474228456616402, pop 0.00022651584004051983
# Epoch 0,30/8278. Total loss: 4112129.75. Loss distribution: feat 0.20165766775608063, style 0.7627503275871277, tv 0.03534939885139465, pop 0.0002426586434012279
# Epoch 0,31/8278. Total loss: 4141484.75. Loss distribution: feat 0.21053022146224976, style 0.7542999386787415, tv 0.03500421717762947, pop 0.0001655718224355951
# Epoch 0,32/8278. Total loss: 4022908.25. Loss distribution: feat 0.19120611250400543, style 0.7721179723739624, tv 0.03642742708325386, pop 0.0002484777942299843
# Epoch 0,33/8278. Total loss: 3992965.25. Loss distribution: feat 0.2092297077178955, style 0.754001259803772, tv 0.03657964617013931, pop 0.00018939439905807376
# Epoch 0,34/8278. Total loss: 4025274.25. Loss distribution: feat 0.22191017866134644, style 0.7413588166236877, tv 0.03657961264252663, pop 0.00015144747158046812
# Epoch 0,35/8278. Total loss: 3952158.0. Loss distribution: feat 0.22637030482292175, style 0.7366060614585876, tv 0.03676816076040268, pop 0.0002554822713136673
# Epoch 0,36/8278. Total loss: 3893177.0. Loss distribution: feat 0.21412034332752228, style 0.748512327671051, tv 0.03719433769583702, pop 0.0001729581708787009
# Epoch 0,37/8278. Total loss: 3823498.5. Loss distribution: feat 0.20785842835903168, style 0.7542301416397095, tv 0.03758670762181282, pop 0.0003247688291594386
# Epoch 0,38/8278. Total loss: 3902114.75. Loss distribution: feat 0.22917842864990234, style 0.7338563799858093, tv 0.03677910193800926, pop 0.00018611787527333945
# Epoch 0,39/8278. Total loss: 3760388.75. Loss distribution: feat 0.21402131021022797, style 0.7468658089637756, tv 0.03882236406207085, pop 0.0002905075380112976
# Traceback (most recent call last):
#   File "/content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle/./train.py", line 383, in <module>
#     x[j] = load_image(imagepaths[i * batchsize + j], image_size)
#   File "/content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle/./train.py", line 130, in load_image
#     image = Image.open(path).convert('RGB')
#   File "/usr/local/lib/python3.10/dist-packages/PIL/Image.py", line 3236, in open
#     prefix = fp.read(16)
# KeyboardInterrupt
# ^C

# %%
# %ls models
