# %%
import os

working_path = os.getcwd()
print(working_path)

if working_path == '/content':
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content/drive/Othercomputers/Il mio computer/chainer-fast-neuralstyle
    # %pip install chainer
# Out:
# c:\Users\fisso-nico\Desktop\Proj\real-time-style-transfer\chainer-fast-neuralstyle

# %%
#import os
#
#if not os.path.exists('./real-time-style-transfer'):
#  !git clone https://github.com/peregoniccolo/real-time-style-transfer

# %%
# !sudo apt-get install dos2unix
# !dos2unix *.sh
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   dos2unix
# 0 upgraded, 1 newly installed, 0 to remove and 16 not upgraded.
# Need to get 384 kB of archives.
# After this operation, 1,367 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dos2unix amd64 7.4.2-2 [384 kB]
# Fetched 384 kB in 0s (965 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package dos2unix.
# (Reading database ... 120831 files and directories currently installed.)
# Preparing to unpack .../dos2unix_7.4.2-2_amd64.deb ...
# Unpacking dos2unix (7.4.2-2) ...
# Setting up dos2unix (7.4.2-2) ...
# Processing triggers for man-db (2.10.2-1) ...
# dos2unix: converting file setup_dataset.sh to Unix format...
# dos2unix: converting file setup_model.sh to Unix format...

# %%
# !sh setup_model.sh
# Out:
# load VGG16 caffemodel
# copy weights
# Copy conv1_1
# Copy conv1_2
# Copy conv2_1
# Copy conv2_2
# Copy conv3_1
# Copy conv3_2
# Copy conv3_3
# Copy conv4_1
# Copy conv4_2
# Copy conv4_3
# Copy conv5_1
# Copy conv5_2
# Copy conv5_3
# save "vgg16.model"
# done

# %%
# !ls sample_images/
# Out:
# clouds.jpg	   output_2.jpg		     prismas.jpg
# colors.jpeg	   output4.jpg		     style_0.jpg
# jeongyeon.jpg	   output5.jpg		     style_1.png
# natasha-russu.jpg  output_keep_colors_1.jpg  style_2.png
# output_0.jpg	   output_keep_colors_2.jpg  test_style.png
# output_1.jpg	   picasso.jpg		     tubingen.jpg

# %%
#!rm ./coco/train2014/COCO_train2014_000000270070.jpg
# !sh setup_dataset.sh --force_unzip
# Out:
# dataset folder exists
# unzipping remaining
# Archive:  train2014.zip
# error:  cannot create ./coco/train2014/COCO_train2014_000000270070.jpg
#         Input/output error
# done

# %%
# !python list_pop.py -f #82783
# Out:
# reading fs.list
# num traning images: 82783

# %%
# TEST
# !python ./train.py -s .\sample_images\altocumulus.jpg -o altocumulus_test -d coco\test100 -e 2 -c 25 -b 10

#!python ./train.py -s sample_images/altocumulus.jpg -e 2 -g 0 -c 25 -b 10 --lambda_style 4 --lambda_feat 2 -a

# TODO bug seconda epoca bug non cancella
# TODO best
# TODO bug cambio numero checkpoint
# Out:
# reading fs.list
# num traning images: 100
# 10 iterations, 2 epochs
# epoch 0
# Traceback (most recent call last):
#   File "c:\Users\fisso-nico\Desktop\Proj\real-time-style-transfer\chainer-fast-neuralstyle\train.py", line 217, in <module>
#     x[j] = load_image(imagepaths[i*batchsize + j], image_size)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\fisso-nico\Desktop\Proj\real-time-style-transfer\chainer-fast-neuralstyle\train.py", line 46, in load_image
#     image = Image.open(path).convert('RGB')
#             ^^^^^^^^^^^^^^^^
#   File "d:\Programmi\conda\envs\STMAE\Lib\site-packages\PIL\Image.py", line 3218, in open
#     fp = builtins.open(filename, "rb")
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'coco/test100/COCO_train2014_000000140667.jpg'

# %%
# %ls models
# Out:
# check_test_style_0_8250.model  presets/            test_style7.state
# check_test_style_0_8250.state  test_style_0.model  test_style8.model
# check_test_style_0_8275.model  test_style_0.state  test_style8.state
# check_test_style_0_8275.state  test_style10.model  test_style9.model
# check_test_style_1_3325.model  test_style10.state  test_style9.state
# check_test_style_1_3325.state  test_style4.model   test_style.model
# check_test_style_1_3350.model  test_style4.state   test_style.state
# check_test_style_1_3350.state  test_style7.model
